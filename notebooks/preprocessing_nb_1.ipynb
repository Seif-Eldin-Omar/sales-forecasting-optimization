# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/explored_train.csv')
df['date'] = pd.to_datetime(df['date'])
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month
df['day_of_week'] = df['date'].dt.day
df['quarter'] = df['date'].dt.quarter
df.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion holiday_type  \
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0      Holiday
# 1   1 2013-01-01          1   BABY CARE    0.0            0      Holiday
# 2   2 2013-01-01          1      BEAUTY    0.0            0      Holiday
# 3   3 2013-01-01          1   BEVERAGES    0.0            0      Holiday
# 4   4 2013-01-01          1       BOOKS    0.0            0      Holiday
#
#      locale locale_name         description transferred  dcoilwtico   city  \
# 0  National     Ecuador  Primer dia del ano       False         NaN  Quito
# 1  National     Ecuador  Primer dia del ano       False         NaN  Quito
# 2  National     Ecuador  Primer dia del ano       False         NaN  Quito
# 3  National     Ecuador  Primer dia del ano       False         NaN  Quito
# 4  National     Ecuador  Primer dia del ano       False         NaN  Quito
#
#        state store_type  cluster  transactions  year  month  week  quarter  \
# 0  Pichincha          D       13           NaN  2013      1     1        1
# 1  Pichincha          D       13           NaN  2013      1     1        1
# 2  Pichincha          D       13           NaN  2013      1     1        1
# 3  Pichincha          D       13           NaN  2013      1     1        1
# 4  Pichincha          D       13           NaN  2013      1     1        1
#
#    day_of_week
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3054348 entries, 0 to 3054347
# Data columns (total 22 columns):
#  #   Column        Dtype
# ---  ------        -----
#  0   id            int64
#  1   date          datetime64[ns]
#  2   store_nbr     int64
#  3   family        object
#  4   sales         float64
#  5   onpromotion   int64
#  6   holiday_type  object
#  7   locale        object
#  8   locale_name   object
#  9   description   object
#  10  transferred   object
#  11  dcoilwtico    float64
#  12  city          object
#  13  state         object
#  14  store_type    object
#  15  cluster       int64
#  16  transactions  float64
#  17  year          int32
#  18  month         int32
#  19  week          int64
#  20  quarter       int32
#  21  day_of_week   int32
# dtypes: datetime64[ns](1), float64(3), int32(4), int64(5), object(9)
# memory usage: 466.1+ MB

# %%
df.describe()
# Out:
#                  id                           date     store_nbr  \
# count  3.054348e+06                        3054348  3.054348e+06
# mean   1.504277e+06  2015-04-26 12:11:45.717619200  2.750000e+01
# min    0.000000e+00            2013-01-01 00:00:00  1.000000e+00
# 25%    7.546768e+05            2014-03-01 00:00:00  1.400000e+01
# 50%    1.507572e+06            2015-04-28 12:00:00  2.750000e+01
# 75%    2.255120e+06            2016-06-22 00:00:00  4.100000e+01
# max    3.000887e+06            2017-08-15 00:00:00  5.400000e+01
# std    8.662610e+05                            NaN  1.558579e+01
#
#               sales   onpromotion    dcoilwtico       cluster  transactions  \
# count  3.054348e+06  3.054348e+06  2.090286e+06  3.054348e+06  2.805231e+06
# mean   3.590209e+02  2.617480e+00  6.807354e+01  8.481481e+00  1.697071e+03
# min    0.000000e+00  0.000000e+00  2.619000e+01  1.000000e+00  5.000000e+00
# 25%    0.000000e+00  0.000000e+00  4.638000e+01  4.000000e+00  1.046000e+03
# 50%    1.100000e+01  0.000000e+00  5.346000e+01  8.500000e+00  1.395000e+03
# 75%    1.960110e+02  0.000000e+00  9.582000e+01  1.300000e+01  2.081000e+03
# max    1.247170e+05  7.410000e+02  1.106200e+02  1.700000e+01  8.359000e+03
# std    1.107286e+03  1.225494e+01  2.569465e+01  4.649735e+00  9.668317e+02
#
#                year         month          week       quarter   day_of_week
# count  3.054348e+06  3.054348e+06  3.054348e+06  3.054348e+06  3.054348e+06
# mean   2.014842e+03  6.222870e+00  2.530863e+01  2.413652e+00  1.565694e+01
# min    2.013000e+03  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# 25%    2.014000e+03  3.000000e+00  1.300000e+01  1.000000e+00  8.000000e+00
# 50%    2.015000e+03  6.000000e+00  2.500000e+01  2.000000e+00  1.600000e+01
# 75%    2.016000e+03  9.000000e+00  3.800000e+01  3.000000e+00  2.300000e+01
# max    2.017000e+03  1.200000e+01  5.300000e+01  4.000000e+00  3.100000e+01
# std    1.345607e+00  3.374251e+00  1.475051e+01  1.095690e+00  8.801398e+00

# %%
df.isna().sum()
# Out:
# id                    0
# date                  0
# store_nbr             0
# family                0
# sales                 0
# onpromotion           0
# holiday_type    2551824
# locale          2551824
# locale_name     2551824
# description     2551824
# transferred     2551824
# dcoilwtico       964062
# city                  0
# state                 0
# store_type            0
# cluster               0
# transactions     249117
# year                  0
# month                 0
# week                  0
# quarter               0
# day_of_week           0
# dtype: int64

# %%
df['date'].index = pd.to_datetime(df['date'])

# %%
df.head()
# Out:
#    id       date  store_nbr      family  sales  onpromotion holiday_type  \
# 0   0 2013-01-01          1  AUTOMOTIVE    0.0            0      Holiday
# 1   1 2013-01-01          1   BABY CARE    0.0            0      Holiday
# 2   2 2013-01-01          1      BEAUTY    0.0            0      Holiday
# 3   3 2013-01-01          1   BEVERAGES    0.0            0      Holiday
# 4   4 2013-01-01          1       BOOKS    0.0            0      Holiday
#
#      locale locale_name         description transferred  dcoilwtico   city  \
# 0  National     Ecuador  Primer dia del ano       False         NaN  Quito
# 1  National     Ecuador  Primer dia del ano       False         NaN  Quito
# 2  National     Ecuador  Primer dia del ano       False         NaN  Quito
# 3  National     Ecuador  Primer dia del ano       False         NaN  Quito
# 4  National     Ecuador  Primer dia del ano       False         NaN  Quito
#
#        state store_type  cluster  transactions  year  month  week  quarter  \
# 0  Pichincha          D       13           NaN  2013      1     1        1
# 1  Pichincha          D       13           NaN  2013      1     1        1
# 2  Pichincha          D       13           NaN  2013      1     1        1
# 3  Pichincha          D       13           NaN  2013      1     1        1
# 4  Pichincha          D       13           NaN  2013      1     1        1
#
#    day_of_week
# 0            1
# 1            1
# 2            1
# 3            1
# 4            1

# %%
pd.Series(df[df['holiday_type'].isna()]['date'].unique())
# Out:
# 0      2013-01-02
# 1      2013-01-03
# 2      2013-01-04
# 3      2013-01-06
# 4      2013-01-07
#           ...
# 1427   2017-08-08
# 1428   2017-08-09
# 1429   2017-08-12
# 1430   2017-08-13
# 1431   2017-08-14
# Length: 1432, dtype: datetime64[ns]

# %% [markdown]
# # Missing values in the `holiday_type` column
#
# We found the **holiday.csv** to be inconsistent with the **train.csv** in context of the date.
# That's why there are near 2.5 Million NaN values in them.
#
# The solution is, we should impute with another value with the meaning of "Not a Holiday" to solve the problem

# %%
df['holiday_type'] = df['holiday_type'].fillna('Normal Day')

# %%
df['locale_name'].unique()
# Out:
# array(['Ecuador', nan, 'Manta', 'Cotopaxi', 'Cuenca', 'Libertad',
#        'Riobamba', 'Puyo', 'Guaranda', 'Imbabura', 'Machala', 'Latacunga',
#        'El Carmen', 'Santo Domingo', 'Cayambe', 'Guayaquil', 'Esmeraldas',
#        'Ambato', 'Ibarra', 'Quevedo', 'Santo Domingo de los Tsachilas',
#        'Santa Elena', 'Quito', 'Loja', 'Salinas'], dtype=object)

# %%
df['locale'].fillna('None', inplace=True)
df['locale_name'].fillna('None', inplace=True)
df['description'].fillna('None', inplace=True)

# %%
df['transferred'].unique()
# Out:
# array([False, nan, True], dtype=object)

# %%
df['transferred'].fillna(False, inplace=True)

# %%
df.isna().sum()
# Out:
# id                   0
# date                 0
# store_nbr            0
# family               0
# sales                0
# onpromotion          0
# holiday_type         0
# locale               0
# locale_name          0
# description          0
# transferred          0
# dcoilwtico      964062
# city                 0
# state                0
# store_type           0
# cluster              0
# transactions    249117
# year                 0
# month                0
# week                 0
# quarter              0
# day_of_week          0
# dtype: int64

# %%
df['dcoilwtico'].fillna(method='ffill', inplace=True)

# %%
df.isna().sum()
# Out:
# id                   0
# date                 0
# store_nbr            0
# family               0
# sales                0
# onpromotion          0
# holiday_type         0
# locale               0
# locale_name          0
# description          0
# transferred          0
# dcoilwtico       14256
# city                 0
# state                0
# store_type           0
# cluster              0
# transactions    249117
# year                 0
# month                0
# week                 0
# quarter              0
# day_of_week          0
# dtype: int64

# %%
df['dcoilwtico'].fillna(method='bfill', inplace=True)

# %% [markdown]
# # Imputing using both, Foraward and Backward fill
# We Imputed the `oil` column with both techniques because of the consequtive missing data

# %%
df.isna().sum()
# Out:
# id                   0
# date                 0
# store_nbr            0
# family               0
# sales                0
# onpromotion          0
# holiday_type         0
# locale               0
# locale_name          0
# description          0
# transferred          0
# dcoilwtico           0
# city                 0
# state                0
# store_type           0
# cluster              0
# transactions    249117
# year                 0
# month                0
# week                 0
# quarter              0
# day_of_week          0
# dtype: int64

# %%
pd.Series(df[df['transactions'].isna()]['date'])
# Out:
# 0         2013-01-01
# 1         2013-01-01
# 2         2013-01-01
# 3         2013-01-01
# 4         2013-01-01
#              ...
# 2838523   2017-04-19
# 2838524   2017-04-19
# 2838525   2017-04-19
# 2838526   2017-04-19
# 2838527   2017-04-19
# Name: date, Length: 249117, dtype: datetime64[ns]

# %%
df[df['transactions'] == 0].shape[0]
# Out:
# 0

# %%
df['transactions'].fillna(0, inplace=True)

# %% [markdown]
# # Imputing the missing values with 0
# > The logic behind: because there are days that has no transactions that were assigned `NaN`, so they were not missing, it meant there were no transactions.

# %%
df.isna().sum()
# Out:
# id              0
# date            0
# store_nbr       0
# family          0
# sales           0
# onpromotion     0
# holiday_type    0
# locale          0
# locale_name     0
# description     0
# transferred     0
# dcoilwtico      0
# city            0
# state           0
# store_type      0
# cluster         0
# transactions    0
# year            0
# month           0
# week            0
# quarter         0
# day_of_week     0
# dtype: int64

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    plt.figure(figsize=(10, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col}')
    plt.show()

# %%
numeric_cols
# Out:
# Index(['id', 'store_nbr', 'sales', 'onpromotion', 'dcoilwtico', 'cluster',
#        'transactions', 'year', 'month', 'week', 'quarter', 'day_of_week'],
#       dtype='object')

# %%
df[df['sales'] == df.sales.max()]
# Out:
#               id       date  store_nbr     family     sales  onpromotion  \
# 2194017  2163723 2016-05-02          2  GROCERY I  124717.0           59
#
#         holiday_type    locale locale_name          description  transferred  \
# 2194017        Event  National     Ecuador  Terremoto Manabi+16        False
#
#          dcoilwtico   city      state store_type  cluster  transactions  year  \
# 2194017       41.67  Quito  Pichincha          D       13        1905.0  2016
#
#          month  week  quarter  day_of_week
# 2194017      5    18        2            2

# %%
max_sales_date = df.loc[df['sales'] == df['sales'].max(), 'date'].iloc[0]

start_date = pd.to_datetime(max_sales_date) - pd.DateOffset(days=17)
end_date = pd.to_datetime(max_sales_date) + pd.DateOffset(days=17)

filt = (df['date'] >= start_date) & (df['date'] <= end_date)
df[filt].groupby('date').first().reset_index()
# Out:
#          date       id  store_nbr      family  sales  onpromotion  \
# 0  2016-04-15  2133054          1  AUTOMOTIVE    5.0            0
# 1  2016-04-16  2134836          1  AUTOMOTIVE    6.0            0
# 2  2016-04-17  2136618          1  AUTOMOTIVE    1.0            0
# 3  2016-04-18  2138400          1  AUTOMOTIVE   14.0            0
# 4  2016-04-19  2140182          1  AUTOMOTIVE    4.0            0
# 5  2016-04-20  2141964          1  AUTOMOTIVE    9.0            0
# 6  2016-04-21  2143746          1  AUTOMOTIVE    4.0            0
# 7  2016-04-22  2145528          1  AUTOMOTIVE    2.0            0
# 8  2016-04-23  2147310          1  AUTOMOTIVE    3.0            0
# 9  2016-04-24  2149092          1  AUTOMOTIVE    0.0            0
# 10 2016-04-25  2150874          1  AUTOMOTIVE   12.0            0
# 11 2016-04-26  2152656          1  AUTOMOTIVE    1.0            0
# 12 2016-04-27  2154438          1  AUTOMOTIVE    8.0            0
# 13 2016-04-28  2156220          1  AUTOMOTIVE    6.0            0
# 14 2016-04-29  2158002          1  AUTOMOTIVE    5.0            0
# 15 2016-04-30  2159784          1  AUTOMOTIVE   12.0            0
# 16 2016-05-01  2161566          1  AUTOMOTIVE    4.0            0
# 17 2016-05-02  2163348          1  AUTOMOTIVE    6.0            0
# 18 2016-05-03  2165130          1  AUTOMOTIVE    3.0            0
# 19 2016-05-04  2166912          1  AUTOMOTIVE   15.0            0
# 20 2016-05-05  2168694          1  AUTOMOTIVE   10.0            0
# 21 2016-05-06  2170476          1  AUTOMOTIVE    5.0            0
# 22 2016-05-07  2172258          1  AUTOMOTIVE    0.0            0
# 23 2016-05-08  2174040          1  AUTOMOTIVE    5.0            0
# 24 2016-05-09  2175822          1  AUTOMOTIVE    3.0            0
# 25 2016-05-10  2177604          1  AUTOMOTIVE    9.0            0
# 26 2016-05-11  2179386          1  AUTOMOTIVE    4.0            0
# 27 2016-05-12  2181168          1  AUTOMOTIVE    3.0            0
# 28 2016-05-13  2182950          1  AUTOMOTIVE    2.0            0
# 11       40.88  Quito  Pichincha          D       13        1727.0  2016
# 12       42.72  Quito  Pichincha          D       13        1761.0  2016
# 13       43.18  Quito  Pichincha          D       13        1718.0  2016
# 14       42.76  Quito  Pichincha          D       13        1903.0  2016
# 15       42.76  Quito  Pichincha          D       13        1314.0  2016
# 16       42.76  Quito  Pichincha          D       13         550.0  2016
# 17       41.67  Quito  Pichincha          D       13        1722.0  2016
# 18       42.52  Quito  Pichincha          D       13        1726.0  2016
# 19       45.29  Quito  Pichincha          D       13        1876.0  2016
# 20       46.03  Quito  Pichincha          D       13        1810.0  2016
# 21       45.98  Quito  Pichincha          D       13        2076.0  2016
# 22       45.98  Quito  Pichincha          D       13        1486.0  2016
# 23       45.98  Quito  Pichincha          D       13         586.0  2016
# 24       44.75  Quito  Pichincha          D       13        1692.0  2016
# 25       43.65  Quito  Pichincha          D       13        1596.0  2016
# 26       43.77  Quito  Pichincha          D       13        1828.0  2016
# 27       44.33  Quito  Pichincha          D       13        1682.0  2016
# 28       44.58  Quito  Pichincha          D       13        1829.0  2016
# 29       44.58  Quito  Pichincha          D       13        1289.0  2016
# 30       44.58  Quito  Pichincha          D       13         543.0  2016
# 31       43.45  Quito  Pichincha          D       13        1794.0  2016
# 32       44.68  Quito  Pichincha          D       13        1688.0  2016
# 33       46.21  Quito  Pichincha          D       13        1687.0  2016
# 34       46.64  Quito  Pichincha          D       13        1697.0  2016
#
#     month  week  quarter  day_of_week
# 0       4    15        2           15
# 1       4    15        2           16
# 2       4    15        2           17
# 3       4    16        2           18
# 4       4    16        2           19
# 5       4    16        2           20
# 6       4    16        2           21
# 7       4    16        2           22
# 8       4    16        2           23
# 9       4    16        2           24
# 10      4    17        2           25
# 11      4    17        2           26
# 12      4    17        2           27
# 13      4    17        2           28
# 14      4    17        2           29
# 15      4    17        2           30
# 16      5    17        2            1
# 17      5    18        2            2
# 18      5    18        2            3
# 19      5    18        2            4
# 20      5    18        2            5
# 21      5    18        2            6
# 22      5    18        2            7
# 23      5    18        2            8
# 24      5    19        2            9
# 25      5    19        2           10
# 26      5    19        2           11
# 27      5    19        2           12
# 28      5    19        2           13
# 29      5    19        2           14
# 30      5    19        2           15
# 31      5    20        2           16
# 32      5    20        2           17
# 33      5    20        2           18
# 34      5    20        2           19

# %% [markdown]
# The sales spike on **2016-05-02** is retained, as it aligns with the aftermath of the April **2016 earthquake** and represents real economic behavior. <br>
# So it cannot be **removed or normalized** because of the important information it contains. <br>
# But to avoid the random spikes that the model would expect, we will make a new column named `is_crisis` to inform us of the presence of a catastrophe. (whether an earthquake, flood or volcano)

# %%
df['is_crisis'] = df['description'].apply(
    lambda x: 1 if isinstance(x, str) and x.startswith('Terremoto Manabi') else 0
)
df['is_crisis'].value_counts()
# Out:
# is_crisis
# 0    2999106
# 1      55242
# Name: count, dtype: int64

# %%
df[df['is_crisis'] == 1].groupby('date').first().reset_index()
# Out:
#          date       id  store_nbr      family  sales  onpromotion  \
# 0  2016-04-16  2134836          1  AUTOMOTIVE    6.0            0
# 1  2016-04-17  2136618          1  AUTOMOTIVE    1.0            0
# 20      5    18        2            6          1
# 21      5    18        2            7          1
# 22      5    18        2            8          1
# 23      5    19        2            9          1
# 24      5    19        2           10          1
# 25      5    19        2           11          1
# 26      5    19        2           12          1
# 27      5    19        2           13          1
# 28      5    19        2           14          1
# 29      5    19        2           15          1
# 30      5    20        2           16          1

# %% [markdown]
# This insures that the model doesn't lose important information while being **robust** to overfitting <br>
# ### Now for the other 2 columns that contain outliers

# %%
df[df['transactions'].max() == df['transactions']].groupby('date').first().reset_index()
# Out:
#         date       id  store_nbr      family  sales  onpromotion holiday_type  \
# 0 2015-12-23  1932942         44  AUTOMOTIVE   16.0            0   Additional
#
#      locale locale_name description  transferred  dcoilwtico   city  \
# 0  National     Ecuador   Navidad-2        False       35.55  Quito
#
#        state store_type  cluster  transactions  year  month  week  quarter  \
# 0  Pichincha          A        5        8359.0  2015     12    52        4
#
#    day_of_week  is_crisis
# 0           23          0

# %%
df['transactions'].median()
# Out:
# 1332.0

# %%
df.nlargest(10, 'onpromotion').groupby('date').first().reset_index()
# Out:
#         date       id  store_nbr     family   sales  onpromotion holiday_type  \
# 0 2016-05-01  2163162         53  GROCERY I  6712.0          718      Holiday
# 1 2016-05-14  2186328         53  GROCERY I  6262.0          717        Event
# 2 2016-05-15  2188110         53  GROCERY I  6154.0          720        Event
# 3 2016-05-21  2198802         53  GROCERY I  5800.0          716   Normal Day
# 4 2016-05-22  2200584         53  GROCERY I  6044.0          726   Normal Day
# 5 2016-05-27  2209494         53  GROCERY I  5601.0          716     Transfer
# 6 2016-05-28  2211276         53  GROCERY I  5846.0          722   Normal Day
# 7 2016-05-29  2213058         53  GROCERY I  6681.0          719   Normal Day
# 8 2016-05-31  2216622         53  GROCERY I  7517.0          741   Normal Day
#
#      locale locale_name                    description  transferred  \
# 0  National     Ecuador                Dia del Trabajo        False
# 1  National     Ecuador            Terremoto Manabi+28        False
# 2  National     Ecuador            Terremoto Manabi+29        False
# 3      None        None                           None        False
# 4      None        None                           None        False
# 5  National     Ecuador  Traslado Batalla de Pichincha        False
# 6      None        None                           None        False
# 7      None        None                           None        False
# 8      None        None                           None        False
#
#    dcoilwtico   city   state store_type  cluster  transactions  year  month  \
# 0       42.76  Manta  Manabi          D       13        1976.0  2016      5
# 1       44.58  Manta  Manabi          D       13        1967.0  2016      5
# 2       44.58  Manta  Manabi          D       13        2026.0  2016      5
# 3       46.22  Manta  Manabi          D       13        1887.0  2016      5
# 4       46.22  Manta  Manabi          D       13        2001.0  2016      5
# 5       47.67  Manta  Manabi          D       13        1798.0  2016      5
# 6       47.67  Manta  Manabi          D       13        1883.0  2016      5
# 7       47.67  Manta  Manabi          D       13        1839.0  2016      5
# 8       48.04  Manta  Manabi          D       13        1950.0  2016      5
#
#    week  quarter  day_of_week  is_crisis
# 0    17        2            1          0
# 1    19        2           14          1
# 2    19        2           15          1
# 3    20        2           21          0
# 4    20        2           22          0
# 5    21        2           27          0
# 6    21        2           28          0
# 7    21        2           29          0
# 8    22        2           31          0

# %% [markdown]
# Most of the outliers are important information that the model can learn from, And by removeing or normalizing them we would lose so much from the data.

# %%
df.columns
# Out:
# Index(['id', 'date', 'store_nbr', 'family', 'sales', 'onpromotion',
#        'holiday_type', 'locale', 'locale_name', 'description', 'transferred',
#        'dcoilwtico', 'city', 'state', 'store_type', 'cluster', 'transactions',
#        'year', 'month', 'week', 'quarter', 'day_of_week', 'is_crisis'],
#       dtype='object')

# %%
df.drop(columns=['id', 'locale_name', 'description'], inplace=True)

# %%
df.head()
# Out:
#         date  store_nbr      family  sales  onpromotion holiday_type  \
# 0 2013-01-01          1  AUTOMOTIVE    0.0            0      Holiday
# 1 2013-01-01          1   BABY CARE    0.0            0      Holiday
# 2 2013-01-01          1      BEAUTY    0.0            0      Holiday
# 3 2013-01-01          1   BEVERAGES    0.0            0      Holiday
# 4 2013-01-01          1       BOOKS    0.0            0      Holiday
#
#      locale  transferred  dcoilwtico   city      state store_type  cluster  \
# 0  National        False       93.14  Quito  Pichincha          D       13
# 1  National        False       93.14  Quito  Pichincha          D       13
# 2  National        False       93.14  Quito  Pichincha          D       13
# 3  National        False       93.14  Quito  Pichincha          D       13
# 4  National        False       93.14  Quito  Pichincha          D       13
#
#    transactions  year  month  week  quarter  day_of_week  is_crisis
# 0           0.0  2013      1     1        1            1          0
# 1           0.0  2013      1     1        1            1          0
# 2           0.0  2013      1     1        1            1          0
# 3           0.0  2013      1     1        1            1          0
# 4           0.0  2013      1     1        1            1          0

# %%
df.set_index('date', inplace=True)
df.head()
# Out:
#             store_nbr      family  sales  onpromotion holiday_type    locale  \
# date
# 2013-01-01          1  AUTOMOTIVE    0.0            0      Holiday  National
# 2013-01-01          1   BABY CARE    0.0            0      Holiday  National
# 2013-01-01          1      BEAUTY    0.0            0      Holiday  National
# 2013-01-01          1   BEVERAGES    0.0            0      Holiday  National
# 2013-01-01          1       BOOKS    0.0            0      Holiday  National
#
#             transferred  dcoilwtico   city      state store_type  cluster  \
# date
# 2013-01-01        False       93.14  Quito  Pichincha          D       13
# 2013-01-01        False       93.14  Quito  Pichincha          D       13
# 2013-01-01        False       93.14  Quito  Pichincha          D       13
# 2013-01-01        False       93.14  Quito  Pichincha          D       13
# 2013-01-01        False       93.14  Quito  Pichincha          D       13
#
#             transactions  year  month  week  quarter  day_of_week  is_crisis
# date
# 2013-01-01           0.0  2013      1     1        1            1          0
# 2013-01-01           0.0  2013      1     1        1            1          0
# 2013-01-01           0.0  2013      1     1        1            1          0
# 2013-01-01           0.0  2013      1     1        1            1          0
# 2013-01-01           0.0  2013      1     1        1            1          0

# %% [markdown]
# # Feature Engineering

# %%
# Lag Feature: Sales 7 days ago
df['sales_lag_7'] = df.groupby(['store_nbr', 'family'])['sales'].shift(7)

# Rolling Mean: Past 7 days
df['rolling_mean_7'] = df.groupby(['store_nbr', 'family'])['sales'].shift(1).rolling(window=7).mean()

# Is Weekend
df['is_weekend'] = df['day_of_week'].isin([5, 6]).astype(int)

# Is Holiday
df['is_holiday'] = df['holiday_type'].notna().astype(int)

# Promotions in Last 7 Days
df['promo_last_7_days'] = df.groupby(['store_nbr', 'family'])['onpromotion'].shift(1).rolling(window=7, min_periods=1).sum()

# %% [markdown]
# ### Description of New Columns in the Feature Engineering Function
#
# 1. **`sales_lag_7`**:
#    - **Description**: This column represents the sales from **7 days ago** for each unique combination of `store_nbr` and `family`. It is a lag feature that helps capture the past sales trend for each store and family.
#    - **Purpose**: The lag feature provides the model with information about how sales behaved in the past, which can be critical in predicting future sales, especially when sales trends are dependent on previous days.
#
# 2. **`rolling_mean_7`**:
#    - **Description**: This column is a **7-day rolling mean** of the sales, calculated by taking the average sales for the previous 7 days (excluding the current day) for each combination of `store_nbr` and `family`.
#    - **Purpose**: The rolling mean smooths out short-term fluctuations in sales and captures the underlying trend and seasonality over the past week. This helps the model understand if sales are generally increasing, decreasing, or following any cyclical patterns, such as those observed on weekends or during promotions.
#
# 3. **`is_weekend`**:
#    - **Description**: This binary column indicates whether the day of the week is a **weekend** (Saturday or Sunday). If the `day_of_week` is either 5 (Saturday) or 6 (Sunday), it is marked as `1`; otherwise, it's marked as `0`.
#    - **Purpose**: Weekends often have different sales patterns compared to weekdays, so this column helps the model understand the effect of weekends on sales. It allows the model to distinguish between weekday and weekend behavior, which may be important for forecasting.
#
# 4. **`is_holiday`**:
#    - **Description**: This binary column indicates whether the day is a **holiday** or not, based on the presence of the `holiday_type` column. If `holiday_type` is not missing (i.e., the day is a holiday), it is marked as `1`; otherwise, it is marked as `0`.
#    - **Purpose**: Sales on holidays may differ from regular days, so this column helps the model account for the impact of holidays on sales. It adds an important external factor that can influence demand, such as special events or shopping behavior around holidays.
#
# 5. **`promo_last_7_days`**:
#    - **Description**: This column represents the total number of **promotions in the past 7 days** for each combination of `store_nbr` and `family`. It is a rolling sum of the `onpromotion` column for the last 7 days, considering any ongoing promotions.
#    - **Purpose**: Promotions often drive sales, so this column helps the model understand the effect of promotions on sales over the past week. It allows the model to capture the impact of promotional activities in predicting future sales.
#
# ---
# These new features will help the model capture various temporal and external factors, such as sales trends, seasonality, weekends, holidays, and promotions, which are essential for improving the accuracy of sales predictions.

# %%
df.isna().sum()
# Out:
# store_nbr                0
# family                   0
# sales                    0
# onpromotion              0
# holiday_type             0
# locale                   0
# transferred              0
# dcoilwtico               0
# city                     0
# state                    0
# store_type               0
# cluster                  0
# transactions             0
# year                     0
# month                    0
# week                     0
# quarter                  0
# day_of_week              0
# is_crisis                0
# sales_lag_7          12474
# rolling_mean_7        1788
# is_weekend               0
# is_holiday               0
# promo_last_7_days     1782
# dtype: int64

# %%
df[df['sales_lag_7'].isna()].groupby('date').first().reset_index()
# Out:
#         date  store_nbr      family  sales  onpromotion holiday_type  \
# 0 2013-01-01          1  AUTOMOTIVE    0.0            0      Holiday
# 1 2013-01-02          1  AUTOMOTIVE    2.0            0   Normal Day
# 2 2013-01-03          1  AUTOMOTIVE    3.0            0   Normal Day
# 3 2013-01-04          1  AUTOMOTIVE    3.0            0   Normal Day
# 4 2013-01-05          1  AUTOMOTIVE    5.0            0     Work Day
# 5 2013-01-06          1  AUTOMOTIVE    2.0            0   Normal Day
# 6 2013-01-07          1  AUTOMOTIVE    0.0            0   Normal Day
#
#      locale  transferred  dcoilwtico   city      state store_type  cluster  \
# 0  National        False       93.14  Quito  Pichincha          D       13
# 1      None        False       93.14  Quito  Pichincha          D       13
# 2      None        False       93.14  Quito  Pichincha          D       13
# 3      None        False       93.14  Quito  Pichincha          D       13
# 4  National        False       93.14  Quito  Pichincha          D       13
# 5      None        False       93.14  Quito  Pichincha          D       13
# 6      None        False       93.14  Quito  Pichincha          D       13
#
#    transactions  year  month  week  quarter  day_of_week  is_crisis  \
# 0           0.0  2013      1     1        1            1          0
# 1        2111.0  2013      1     1        1            2          0
# 2        1833.0  2013      1     1        1            3          0
# 3        1863.0  2013      1     1        1            4          0
# 4        1509.0  2013      1     1        1            5          0
# 5         520.0  2013      1     1        1            6          0
# 6        1807.0  2013      1     2        1            7          0
#
#    sales_lag_7  rolling_mean_7  is_weekend  is_holiday  promo_last_7_days
# 0          NaN             NaN           0           1                NaN
# 1          NaN        0.000000           0           1                0.0
# 2          NaN        0.285714           0           1                0.0
# 3          NaN      109.500857           0           1                0.0
# 4          NaN       86.213714           1           1                0.0
# 5          NaN       57.953143           1           1                0.0
# 6          NaN       89.325714           0           1                0.0

# %%
df['sales_lag_7'].fillna(method='bfill', inplace=True)

# %% [markdown]
# The first week is messing because there are no previous week to calculate the lag of it

# %%
df[df['rolling_mean_7'].isna()].groupby('date').first().reset_index()
# Out:
#         date  store_nbr      family  sales  onpromotion holiday_type  \
# 0 2013-01-01          1  AUTOMOTIVE    0.0            0      Holiday
# 1 2013-01-02          1  AUTOMOTIVE    2.0            0   Normal Day
#
#      locale  transferred  dcoilwtico   city      state store_type  cluster  \
# 0  National        False       93.14  Quito  Pichincha          D       13
# 1      None        False       93.14  Quito  Pichincha          D       13
#
#    transactions  year  month  week  quarter  day_of_week  is_crisis  \
# 0           0.0  2013      1     1        1            1          0
# 1        2111.0  2013      1     1        1            2          0
#
#    sales_lag_7  rolling_mean_7  is_weekend  is_holiday  promo_last_7_days
# 0          0.0             NaN           0           1                NaN
# 1          0.0             NaN           0           1                0.0

# %%
df['rolling_mean_7'].fillna(method='bfill', inplace=True)

# %% [markdown]
# The first 2 days are missing because there are no sales on those days

# %%
df[df['promo_last_7_days'].isna()].groupby('date').first().reset_index()
# Out:
#         date  store_nbr      family  sales  onpromotion holiday_type  \
# 0 2013-01-01          1  AUTOMOTIVE    0.0            0      Holiday
#
#      locale  transferred  dcoilwtico   city      state store_type  cluster  \
# 0  National        False       93.14  Quito  Pichincha          D       13
#
#    transactions  year  month  week  quarter  day_of_week  is_crisis  \
# 0           0.0  2013      1     1        1            1          0
#
#    sales_lag_7  rolling_mean_7  is_weekend  is_holiday  promo_last_7_days
# 0          0.0             0.0           0           1                NaN

# %%
df['promo_last_7_days'].fillna(method='bfill', inplace=True)

# %% [markdown]
# The 1st day has missing values because there are no promotions were on that day

# %%
df.isna().sum()
# Out:
# store_nbr            0
# family               0
# sales                0
# onpromotion          0
# holiday_type         0
# locale               0
# transferred          0
# dcoilwtico           0
# city                 0
# state                0
# store_type           0
# cluster              0
# transactions         0
# year                 0
# month                0
# week                 0
# quarter              0
# day_of_week          0
# is_crisis            0
# sales_lag_7          0
# rolling_mean_7       0
# is_weekend           0
# is_holiday           0
# promo_last_7_days    0
# dtype: int64
