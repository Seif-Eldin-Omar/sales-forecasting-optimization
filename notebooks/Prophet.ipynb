# %%
#! pip install prophet
#! pip install pystan==2.19.1.1
#! pip install prophet --no-cache-dir --force-reinstall
import pandas as pd
import numpy as np
import warnings
from prophet import Prophet
from sklearn.preprocessing import MinMaxScaler, LabelEncoder

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../data/cleaned_data.csv', parse_dates=['date'])
df.head()
# Out:
#         date  store_nbr      family  sales  onpromotion holiday_type  \
# 0 2013-01-01          1  AUTOMOTIVE   0.00            0      Holiday
# 1 2013-01-01          1   BABY CARE   0.00            0      Holiday
# 2 2013-01-01          1      BEAUTY   0.00            0      Holiday
# 3 2013-01-01          1   BEVERAGES   0.00            0      Holiday
# 4 2013-01-01          1       BOOKS   0.00            0      Holiday
#
#      locale  transferred  dcoilwtico   city      state store_type  cluster  \
# 0  National        False       93.14  Quito  Pichincha          D       13
# 1  National        False       93.14  Quito  Pichincha          D       13
# 2  National        False       93.14  Quito  Pichincha          D       13
# 3  National        False       93.14  Quito  Pichincha          D       13
# 4  National        False       93.14  Quito  Pichincha          D       13
#
#    transactions  year  month  week  quarter day_of_week  is_crisis  \
# 0          0.00  2013      1     1        1     Tuesday          0
# 1          0.00  2013      1     1        1     Tuesday          0
# 2          0.00  2013      1     1        1     Tuesday          0
# 3          0.00  2013      1     1        1     Tuesday          0
# 4          0.00  2013      1     1        1     Tuesday          0
#
#    sales_lag_7  rolling_mean_7  is_weekend  is_holiday  promo_last_7_days  \
# 0         0.00            0.00           0           1               0.00
# 1         0.00            0.00           0           1               0.00
# 2         0.00            0.00           0           1               0.00
# 3         0.00            0.00           0           1               0.00
# 4         0.00            0.00           0           1               0.00
#
#    days_to_holiday  promotion_status
# 0                0  Not On Promotion
# 1                0  Not On Promotion
# 2                0  Not On Promotion
# 3                0  Not On Promotion
# 4                0  Not On Promotion

# %%
feature_cols = [
    'onpromotion', 'transactions', 'dcoilwtico',
    'sales_lag_7', 'rolling_mean_7',
    'is_holiday', 'is_weekend', 'promo_last_7_days',
    'days_to_holiday', 'year', 'month', 'week', 'day_of_week'
]

target_col = 'sales'

# %%
categorical_cols = [
    'holiday_type', 'locale', 'transferred', 'city', 'state',
    'store_type', 'promotion_status', 'day_of_week'
]

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col].astype(str))

# %%
scaler = MinMaxScaler()
df = scaler.fit_transform(df[feature_cols + [target_col]])

# %%
df = df.sort_values('date')
train = df[df['date'] < '2017-01-01']
test = df[df['date'] >= '2017-01-01']
train.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df = df.sort_values('date')
#       2 train = df[df['date'] < '2017-01-01']
#       3 test = df[df['date'] >= '2017-01-01']
#
# AttributeError: 'numpy.ndarray' object has no attribute 'sort_values'

# %%
df_prophet = df.rename(columns={'date': 'ds', 'sales': 'y'})
df_prophet['ds'] = pd.to_datetime(df_prophet['ds'])
df_prophet['onpromotion'] = df_prophet['onpromotion'].astype(float)
df_prophet['is_holiday'] = df_prophet['is_holiday'].astype(float)
df_prophet['sales_lag_7'] = df_prophet['sales_lag_7'].astype(float)
df_prophet['rolling_mean_7'] = df_prophet['rolling_mean_7'].astype(float)

# %%
train.head()
# Out:
#            date  store_nbr        family  sales  onpromotion holiday_type  \
# 0    2013-01-01          1    AUTOMOTIVE   0.00            0      Holiday
# 1194 2013-01-01         42   CELEBRATION   0.00            0      Holiday
# 1193 2013-01-01         42  BREAD/BAKERY   0.00            0      Holiday
# 1192 2013-01-01         42         BOOKS   0.00            0      Holiday
# 1191 2013-01-01         42     BEVERAGES   0.00            0      Holiday
#
#         locale  transferred  dcoilwtico    city      state store_type  \
# 0     National        False       93.14   Quito  Pichincha          D
# 1194  National        False       93.14  Cuenca      Azuay          D
# 1193  National        False       93.14  Cuenca      Azuay          D
# 1192  National        False       93.14  Cuenca      Azuay          D
# 1191  National        False       93.14  Cuenca      Azuay          D
#
#       cluster  transactions  year  month  week  quarter day_of_week  \
# 0          13          0.00  2013      1     1        1     Tuesday
# 1194        2          0.00  2013      1     1        1     Tuesday
# 1193        2          0.00  2013      1     1        1     Tuesday
# 1192        2          0.00  2013      1     1        1     Tuesday
# 1191        2          0.00  2013      1     1        1     Tuesday
#
#       is_crisis  sales_lag_7  rolling_mean_7  is_weekend  is_holiday  \
# 0             0         0.00            0.00           0           1
# 1194          0         0.00            0.00           0           1
# 1193          0         0.00            0.00           0           1
# 1192          0         0.00            0.00           0           1
# 1191          0         0.00            0.00           0           1
#
#       promo_last_7_days  days_to_holiday  promotion_status
# 0                  0.00                0  Not On Promotion
# 1194               0.00                0  Not On Promotion
# 1193               0.00                0  Not On Promotion
# 1192               0.00                0  Not On Promotion
# 1191               0.00                0  Not On Promotion

# %%
train = df_prophet[df_prophet['ds'] < '2017-01-01']
test = df_prophet[df_prophet['ds'] >= '2017-01-01']
test.head()
# Out:
#                 ds  store_nbr      family    y  onpromotion holiday_type  \
# 2643889 2017-01-01         41     POULTRY 0.00         0.00      Holiday
# 2643897 2017-01-01         42   BEVERAGES 0.00         0.00      Holiday
# 2643896 2017-01-01         42      BEAUTY 0.00         0.00      Holiday
# 2643895 2017-01-01         42   BABY CARE 0.00         0.00      Holiday
# 2643894 2017-01-01         42  AUTOMOTIVE 0.00         0.00      Holiday
#
#            locale  transferred  dcoilwtico     city   state store_type  \
# 2643889  National         True       52.01  Machala  El Oro          D
# 2643897  National         True       52.01   Cuenca   Azuay          D
# 2643896  National         True       52.01   Cuenca   Azuay          D
# 2643895  National         True       52.01   Cuenca   Azuay          D
# 2643894  National         True       52.01   Cuenca   Azuay          D
#
#          cluster  transactions  year  month  week  quarter day_of_week  \
# 2643889        4          0.00  2017      1    52        1      Sunday
# 2643897        2          0.00  2017      1    52        1      Sunday
# 2643896        2          0.00  2017      1    52        1      Sunday
# 2643895        2          0.00  2017      1    52        1      Sunday
# 2643894        2          0.00  2017      1    52        1      Sunday
#
#          is_crisis  sales_lag_7  rolling_mean_7  is_weekend  is_holiday  \
# 2643889          0       498.33          191.32           1        1.00
# 2643897          0      3359.00         1015.18           1        1.00
# 2643896          0         7.00          466.22           1        1.00
# 2643895          0         0.00          491.57           1        1.00
# 2643894          0         7.00          494.43           1        1.00
#
#          promo_last_7_days  days_to_holiday  promotion_status
# 2643889              16.00             1461  Not On Promotion
# 2643897              76.00             1461  Not On Promotion
# 2643896              10.00             1461  Not On Promotion
# 2643895               9.00             1461  Not On Promotion
# 2643894               9.00             1461  Not On Promotion

# %%
m = Prophet()
m.add_regressor('sales_lag_7')
m.add_regressor('rolling_mean_7')
m.add_regressor('onpromotion')
m.add_regressor('is_holiday')

# %%
m.fit(train)
# Out:
# 14:42:48 - cmdstanpy - INFO - Chain [1] start processing
# 15:05:20 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = test[['ds', 'sales_lag_7', 'rolling_mean_7', 'onpromotion', 'is_holiday']].sample(n=20000, random_state=42)
forecast = m.predict(future)

# %%
forecast.head()
# Out:
#           ds  trend  yhat_lower  yhat_upper  trend_lower  trend_upper  \
# 0 2017-01-01 277.42     5385.84     6444.68       277.42       277.42
# 1 2017-01-01 277.42     -479.36      496.91       277.42       277.42
# 2 2017-01-01 277.42     -539.36      455.04       277.42       277.42
# 3 2017-01-01 277.42    14347.73    15319.03       277.42       277.42
# 4 2017-01-01 277.42     -409.25      611.12       277.42       277.42
#
#    additive_terms  additive_terms_lower  additive_terms_upper  \
# 0         5620.18               5620.18               5620.18
# 1         -273.09               -273.09               -273.09
# 2         -315.84               -315.84               -315.84
# 3        14535.65              14535.65              14535.65
# 4         -164.46               -164.46               -164.46
#
#    extra_regressors_additive  extra_regressors_additive_lower  \
# 0                    5621.81                          5621.81
# 1                    -271.46                          -271.46
# 2                    -314.21                          -314.21
# 3                   14537.28                         14537.28
# 4                    -162.83                          -162.83
#
#    extra_regressors_additive_upper  is_holiday  is_holiday_lower  \
# 0                          5621.81        4.56              4.56
# 1                          -271.46        4.56              4.56
# 2                          -314.21        4.56              4.56
# 3                         14537.28        4.56              4.56
# 4                          -162.83        4.56              4.56
#
#    is_holiday_upper  onpromotion  onpromotion_lower  onpromotion_upper  \
# 0              4.56        -8.91              -8.91              -8.91
# 1              4.56        -8.91              -8.91              -8.91
# 2              4.56        -8.91              -8.91              -8.91
# 3              4.56        -8.91              -8.91              -8.91
# 4              4.56        -8.91              -8.91              -8.91
#
#    rolling_mean_7  rolling_mean_7_lower  rolling_mean_7_upper  sales_lag_7  \
# 0          109.93                109.93                109.93      5516.23
# 1           31.78                 31.78                 31.78      -298.88
# 2           -9.19                 -9.19                 -9.19      -300.67
# 3          297.27                297.27                297.27     14244.36
# 4           70.88                 70.88                 70.88      -229.35
#
#    sales_lag_7_lower  sales_lag_7_upper  weekly  weekly_lower  weekly_upper  \
# 0            5516.23            5516.23   12.03         12.03         12.03
# 1            -298.88            -298.88   12.03         12.03         12.03
# 2            -300.67            -300.67   12.03         12.03         12.03
# 3           14244.36           14244.36   12.03         12.03         12.03
# 4            -229.35            -229.35   12.03         12.03         12.03
#
#    yearly  yearly_lower  yearly_upper  multiplicative_terms  \
# 0  -13.65        -13.65        -13.65                  0.00
# 1  -13.65        -13.65        -13.65                  0.00
# 2  -13.65        -13.65        -13.65                  0.00
# 3  -13.65        -13.65        -13.65                  0.00
# 4  -13.65        -13.65        -13.65                  0.00
#
#    multiplicative_terms_lower  multiplicative_terms_upper     yhat
# 0                        0.00                        0.00  5897.60
# 1                        0.00                        0.00     4.33
# 2                        0.00                        0.00   -38.42
# 3                        0.00                        0.00 14813.06
# 4                        0.00                        0.00   112.96

# %%
results = forecast[['ds', 'yhat']].merge(test[['ds', 'y']], on='ds', how='inner')
results.rename(columns={'y': 'actual', 'yhat': 'predicted'}, inplace=True)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(results['actual'], results['predicted'])
mse = mean_squared_error(results['actual'], results['predicted'])
rmse = mse ** 0.5
r2 = r2_score(results['actual'], results['predicted'])

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R² Score: {r2:.2f}")
# Out:
# MAE: 835.36
# MSE: 3554898.81
# RMSE: 1885.44
# R² Score: -0.90
